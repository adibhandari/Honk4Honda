# %% [markdown]
# # This notebook is EDA for the Honk4Honda data challenge (unsupervised learning)

# %% [markdown]
# # Goal is to (as Honda) find promising markets to expand to

# %% [markdown]
# ## First import modules and data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

data = pd.read_csv('./data/craigslistVehiclesFull.csv')
data.head()

# %%
len(data)
# Out:
# 1723065

# %% [markdown]
# # Explore data

# %%
# Check for any missing data
print("Table size -", end=' ')
print(data.shape)

print("Checking for missing values..")
# Number of missing values in each column of training data
missing_val_count_by_column = (data.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])

# Get names of columns with missing values
missing_cols = [col for col in data.columns
                     if data[col].isnull().any()]
# Out:
# Table size - (1723065, 26)
# Checking for missing values..
# year               6315
# manufacturer     136414
# make              69699
# condition        700790
# cylinders        691291
# fuel              10367
# odometer         564054
# title_status       2554
# transmission       9022
# vin             1118215
# drive            661884
# size            1123967
# type             702931
# paint_color      695650
# image_url             1
# county_fips       58833
# county_name       58833
# state_fips        58833
# state_code        58833
# weather           59428
# dtype: int64

# %%
data.columns
# Out:
# Index(['url', 'city', 'price', 'year', 'manufacturer', 'make', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'vin',
#        'drive', 'size', 'type', 'paint_color', 'image_url', 'lat', 'long',
#        'county_fips', 'county_name', 'state_fips', 'state_code', 'state_name',
#        'weather'],
#       dtype='object')

# %%
len(missing_cols)
# Out:
# 20

# %%
# What's special about the missing states
data[data['state_code'].isnull()]
# Out:
#                                                        url     city  price  \
# 8        https://soo.craigslist.ca/cto/d/ebike-red-zone...      soo   2700
# 9        https://soo.craigslist.ca/ctd/d/2003-ford-excu...      soo  12995
# 10       https://soo.craigslist.ca/cto/d/2006-chev-expr...      soo   4000
# 11       https://soo.craigslist.ca/cto/d/2002-chev-crew...      soo  13000
# 12       https://soo.craigslist.ca/cto/d/2016-hyundai-s...      soo  21695
# ...                                                    ...      ...    ...
# 1723010  https://reddeer.craigslist.ca/ctd/d/2015-kia-f...  reddeer  10850
# 1723011  https://reddeer.craigslist.ca/ctd/d/sold-but-n...  reddeer  17995
# 1723012  https://reddeer.craigslist.ca/ctd/d/2013-kia-s...  reddeer  19995
# 1723013  https://reddeer.craigslist.ca/cto/d/2012-kia-o...  reddeer  10000
# 1723041  https://skeena.craigslist.ca/ctd/d/2019-isuzu-...   skeena  70999
#
#            year manufacturer                 make  condition     cylinders  \
# 8        2018.0          NaN                Ebike  excellent           NaN
# 9        2003.0         ford            excursion  excellent  10 cylinders
# 10       2006.0         chev     express 2500 van       good   6 cylinders
# 11       2002.0    chevrolet              2500 hd  excellent   8 cylinders
# 12       2016.0      hyundai               sonata   like new   4 cylinders
# ...         ...          ...                  ...        ...           ...
# 1723010  2015.0          kia     forte 4dr sdn lx        NaN   4 cylinders
# 1723011  2013.0       nissan              leaf sl        NaN           NaN
# 1723012  2013.0          kia       sorento ex 4wd        NaN   6 cylinders
# 1723013  2012.0          kia  optima lx 4dr sedan  excellent   4 cylinders
# 1723041  2019.0          NaN         ISUZU NPR-HD        new           NaN
#
#              fuel  odometer  ... paint_color  \
# 8        electric       NaN  ...         red
# 9             gas  236000.0  ...        blue
# 10            gas  138000.0  ...       white
# 11         diesel  350000.0  ...       white
# 12            gas   44814.0  ...       white
# ...           ...       ...  ...         ...
# 1723010       gas   29400.0  ...         NaN
# 1723011  electric   52389.0  ...         NaN
# 1723012       gas   70200.0  ...         NaN
# 1723013       gas   78000.0  ...        blue
# 1723041    diesel       NaN  ...         NaN
#
#                                                  image_url        lat  \
# 8        https://images.craigslist.org/01111_7YfxuQ9Nxu...  46.509803
# 9        https://images.craigslist.org/00707_97tX51ryfc...  46.514191
# 10       https://images.craigslist.org/00J0J_fovkGAUCQI...  46.497529
# 11       https://images.craigslist.org/00V0V_bN5BoWGnSS...  46.497529
# 12       https://images.craigslist.org/00z0z_fLBdcucFWW...  46.517791
# ...                                                    ...        ...
# 1723010  https://images.craigslist.org/00t0t_b46ljc5h29...  49.172550
# 1723011  https://images.craigslist.org/00303_7xGQ0mFuzF...  49.172550
# 1723012  https://images.craigslist.org/00000_8YqcDnJ2YS...  49.172550
# 1723013  https://images.craigslist.org/00L0L_85RjFB9r13...  52.252165
# 1723041  https://images.craigslist.org/00E0E_hmCnIrtpUn...  49.130744
#
#                long county_fips county_name state_fips state_code  state_name  \
# 8        -84.257825         NaN         NaN        NaN        NaN      FAILED
# 9        -84.291307         NaN         NaN        NaN        NaN      FAILED
# 10       -84.467464         NaN         NaN        NaN        NaN      FAILED
# 11       -84.467464         NaN         NaN        NaN        NaN      FAILED
# 12       -84.342291         NaN         NaN        NaN        NaN      FAILED
# ...             ...         ...         ...        ...        ...         ...
# 1723010 -123.078064         NaN         NaN        NaN        NaN      FAILED
# 1723011 -123.078064         NaN         NaN        NaN        NaN      FAILED
# 1723012 -123.078064         NaN         NaN        NaN        NaN      FAILED
# 1723013 -113.795804         NaN         NaN        NaN        NaN      FAILED
# 1723041 -123.089055         NaN         NaN        NaN        NaN      FAILED
#
#          weather
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# ...          ...
# 1723010      NaN
# 1723011      NaN
# 1723012      NaN
# 1723013      NaN
# 1723041      NaN
#
# [58833 rows x 26 columns]

# %%
# Seems like these countries throw an error and state_name is failed, remove these and check again for missing values
data = data[data['state_name'] != 'FAILED']

# %% [markdown]
# ### Not interested in data where manufacturer is null. Drop these columns

# %%
data = data[data['manufacturer'].notna()]

# %%
# recheck for any missing data
print("Table size -", end=' ')
print(data.shape)

print("Checking for missing values..")
# Number of missing values in each column of training data
missing_val_count_by_column = (data.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])

# Get names of columns with missing values
missing_cols = [col for col in data.columns
                     if data[col].isnull().any()]
# Out:
# Table size - (1531482, 24)
# Checking for missing values..
# year              5303
# make             68121
# condition       626974
# cylinders       599905
# fuel              8716
# odometer        477171
# title_status      1250
# transmission      7312
# vin             969314
# drive           569684
# size            995046
# type            606351
# paint_color     601047
# weather            509
# dtype: int64

# %%
# what's going on with weather? Only missing for district of columbia
data[data['weather'].isnull()]['state_name'].value_counts()
# Out:
# District of Columbia    509
# Name: state_name, dtype: int64

# %%
# set this temp = average temp in Maryland
data.loc[(data['state_name'] == 'District of Columbia'), 'weather'] = data.loc[(data['state_name'] == 'Maryland'), 'weather'].mean()

# %%
# recheck for any missing data
print("Table size -", end=' ')
print(data.shape)

print("Checking for missing values..")
# Number of missing values in each column of training data
missing_val_count_by_column = (data.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])

# Get names of columns with missing values
missing_cols = [col for col in data.columns
                     if data[col].isnull().any()]
# Out:
# Table size - (1531482, 24)
# Checking for missing values..
# year              5303
# make             68121
# condition       626974
# cylinders       599905
# fuel              8716
# odometer        477171
# title_status      1250
# transmission      7312
# vin             969314
# drive           569684
# size            995046
# type            606351
# paint_color     601047
# dtype: int64

# %% [markdown]
# ## Remove some columns from model

# %%
data['image_url'][0]
# Out:
# 'https://images.craigslist.org/00i0i_2ggH1eKDNKZ_600x450.jpg'

# %% [markdown]
# ### I'm sure webscraping some of these links would be useful some day but as of today not considering them
# ### Also the links are bad (404)

# %%
data = data.drop(['url','image_url'], axis=1)
data.head()
# Out:
#        city  price    year manufacturer                   make condition  \
# 0  marshall  11900  2010.0        dodge          challenger se      good
# 2  marshall  17550  2008.0         ford                  f-150       NaN
# 3  marshall   2800  2004.0         ford                 taurus      good
# 5  marshall   9900  2007.0          gmc                  yukon      good
# 6  marshall  12500  2015.0         jeep  patriot high altitude  like new
#
#      cylinders fuel  odometer title_status  ...   type paint_color        lat  \
# 0  6 cylinders  gas   43600.0        clean  ...  coupe         red  43.477500
# 2          NaN  gas       NaN        clean  ...    NaN         NaN  44.141500
# 3  6 cylinders  gas  168591.0        clean  ...  sedan        grey  43.284500
# 5  8 cylinders  gas  169000.0        clean  ...    NaN         NaN  43.328149
# 6  4 cylinders  gas   39500.0      rebuilt  ...    SUV        grey  43.548600
#
#          long county_fips county_name  state_fips  state_code    state_name  \
# 0  -96.704100     46083.0     Lincoln        46.0          SD  South Dakota
# 2 -103.205200     46093.0       Meade        46.0          SD  South Dakota
# 3  -95.593000     19143.0     Osceola        19.0          IA          Iowa
# 5  -96.774445     46083.0     Lincoln        46.0          SD  South Dakota
# 6  -96.633200     46099.0   Minnehaha        46.0          SD  South Dakota
#
#   weather
# 0    38.0
# 2    38.0
# 3    47.0
# 5    38.0
# 6    38.0
#
# [5 rows x 24 columns]

# %%
# 446 cities in dataset
data['city'].value_counts()
# Out:
# cosprings      7814
# grandrapids    7702
# anchorage      7690
# sacramento     7685
# omaha          7585
#                ...
# halifax           3
# kelowna           2
# abbotsford        2
# vancouver         1
# toronto           1
# Name: city, Length: 446, dtype: int64

# %%
# 51 states in dataset
data['state_name'].value_counts()
# Out:
# California              141697
# Florida                 101407
# Texas                    88418
# Michigan                 73853
# New York                 65098
# North Carolina           58968
# Ohio                     57263
# Pennsylvania             53026
# Wisconsin                49804
# Washington               48551
# Virginia                 43099
# Oregon                   43065
# Colorado                 38343
# Tennessee                38327
# Missouri                 36985
# Minnesota                34860
# Illinois                 32549
# Georgia                  31869
# Indiana                  29524
# New Jersey               29288
# Massachusetts            29043
# Iowa                     27423
# South Carolina           26119
# Alabama                  25667
# Arizona                  25469
# Connecticut              21877
# Oklahoma                 21524
# Maryland                 20397
# Kentucky                 19732
# Montana                  18662
# Idaho                    18658
# Nebraska                 17863
# Arkansas                 17637
# Louisiana                17547
# Kansas                   17493
# Mississippi              14608
# Nevada                   12540
# New Mexico               11780
# Alaska                   11546
# New Hampshire            10155
# South Dakota              8174
# Utah                      6189
# Vermont                   6189
# Rhode Island              6031
# Maine                     5679
# West Virginia             5212
# Delaware                  5153
# North Dakota              4160
# Wyoming                   2433
# District of Columbia       509
# Hawaii                      19
# Name: state_name, dtype: int64

# %%
# 117 years in dataset, some very possibly wrong ones (302, 718)
print(len(data['year'].value_counts()))
data['year'].value_counts()
# Out:
# 117
# 2007.0    98127
# 2008.0    94059
# 2006.0    91160
# 2015.0    85588
# 2005.0    83696
#           ...
# 1906.0        2
# 1902.0        2
# 1907.0        1
# 1905.0        1
# 1903.0        1
# Name: year, Length: 117, dtype: int64

# %%
# First car was in 1885 so take dates between 1885 and 2020 only, new value counts
data = data[(data['year'] >= 1885) & (data['year'] <= 2020)]
data['year'].value_counts()
# Out:
# 2007.0    98127
# 2008.0    94059
# 2006.0    91160
# 2015.0    85588
# 2005.0    83696
#           ...
# 1906.0        2
# 1902.0        2
# 1907.0        1
# 1905.0        1
# 1903.0        1
# Name: year, Length: 117, dtype: int64

# %%
# 53 brands, can group some together eg (mercedes-benz, mercedesbenz), (chevrolet, chevy, chev). honda is overall #4
print(len(data['manufacturer'].value_counts()))
data['manufacturer'].value_counts()
# Out:
# 43
# ford               286825
# chevrolet          256115
# toyota             113267
# honda               86059
# nissan              76993
# dodge               72771
# jeep                72533
# gmc                 67845
# ram                 54656
# bmw                 41161
# volkswagen          35837
# hyundai             30856
# chrysler            30397
# mercedes-benz       29187
# subaru              28376
# cadillac            24591
# kia                 22708
# buick               22443
# pontiac             21840
# mazda               21208
# lexus               20020
# acura               16959
# audi                14218
# lincoln             12629
# infiniti            11636
# volvo               11007
# mercury             10229
# mitsubishi          10068
# saturn               9290
# mini                 6157
# rover                5152
# jaguar               4180
# fiat                 1684
# harley-davidson       835
# datsun                598
# infinity              500
# ferrari               221
# alfa-romeo            212
# porche                111
# aston-martin           94
# morgan                 11
# noble                   2
# hennessey               1
# Name: manufacturer, dtype: int64

# %%
data.loc[((data['manufacturer'] == 'mercedesbenz') | (data['manufacturer'] == 'mercedes')), 
         'manufacturer'] = 'mercedes-benz'

# %%
data.loc[((data['manufacturer'] == 'chevy') | (data['manufacturer'] == 'chev')), 
         'manufacturer'] = 'chevrolet'

# %%
data.loc[(data['manufacturer'] == 'vw'), 'manufacturer'] = 'volkswagen'

# %%
data.loc[(data['manufacturer'] == 'aston'), 'manufacturer'] = 'aston-martin'

# %%
data.loc[((data['manufacturer'] == 'land rover') | (data['manufacturer'] == 'landrover')), 
         'manufacturer'] = 'rover'

# %%
data.loc[(data['manufacturer'] == 'alfa'), 'manufacturer'] = 'alfa-romeo'

# %%
data.loc[(data['manufacturer'] == 'harley'), 'manufacturer'] = 'harley-davidson'

# %%
# recheck manufacturers, 43 unique
print(len(data['manufacturer'].value_counts()))
data['manufacturer'].value_counts()
# Out:
# 43
# ford               286825
# chevrolet          256115
# toyota             113267
# honda               86059
# nissan              76993
# dodge               72771
# jeep                72533
# gmc                 67845
# ram                 54656
# bmw                 41161
# volkswagen          35837
# hyundai             30856
# chrysler            30397
# mercedes-benz       29187
# subaru              28376
# cadillac            24591
# kia                 22708
# buick               22443
# pontiac             21840
# mazda               21208
# lexus               20020
# acura               16959
# audi                14218
# lincoln             12629
# infiniti            11636
# volvo               11007
# mercury             10229
# mitsubishi          10068
# saturn               9290
# mini                 6157
# rover                5152
# jaguar               4180
# fiat                 1684
# harley-davidson       835
# datsun                598
# infinity              500
# ferrari               221
# alfa-romeo            212
# porche                111
# aston-martin           94
# morgan                 11
# noble                   2
# hennessey               1
# Name: manufacturer, dtype: int64

# %% [markdown]
# # Explore on a state-wise basis

# %% [markdown]
# ## What's special about Omaha, NE? Mentioned that they found a strong regional demand

# %%
data.loc[data['state_name'] == 'Nebraska','manufacturer'].value_counts().head(10)
# Out:
# ford         3972
# chevrolet    3765
# dodge         941
# gmc           869
# toyota        862
# nissan        833
# jeep          771
# honda         763
# ram           622
# chrysler      527
# Name: manufacturer, dtype: int64

# %%
data.loc[(data['city'] == 'omaha') & (data['state_name'] == 'Nebraska'),'manufacturer'].value_counts().head(10)
# Out:
# ford         1262
# chevrolet    1125
# nissan        358
# dodge         347
# toyota        337
# honda         313
# jeep          259
# gmc           243
# ram           217
# chrysler      192
# Name: manufacturer, dtype: int64

# %%
# There is definitely an increase in demand for Honda in Omaha
print(f'Honda/Ford in Omaha vs all of Nebraska = {round(763/3972,3)}:{round(313/1262,3)}')
# Out:
# Honda/Ford in Omaha vs all of Nebraska = 0.192:0.248

# %% [markdown]
# ### A better representation would be market share so let's do that

# %%
# There is definitely an increase in demand for Honda in Omaha
ms_om = len(data[(data['city'] == 'omaha') & (data['state_name'] == 'Nebraska') & (data['manufacturer'] == 'honda')])/len(data[(data['city'] == 'omaha') & (data['state_name'] == 'Nebraska')])
ms_ne = len(data[(data['state_name'] == 'Nebraska') & (data['manufacturer'] == 'honda')])/len(data[(data['state_name'] == 'Nebraska')])
print(f'Market share of Honda in Omaha vs all of Nebraska = {round(ms_om,3)}:{round(ms_ne,3)}')
# Out:
# Market share of Honda in Omaha vs all of Nebraska = 0.051:0.043

# %%
# What is overall market share? Weirdly greater than Omaha. I guess bc opportunity?
ms_overall = len(data[(data['manufacturer'] == 'honda')])/len(data)
print(f'Market share of Honda in US overall = {round(ms_overall,3)}')
# Out:
# Market share of Honda in US overall = 0.056

# %% [markdown]
# # Overall I want to do some kind of clustering
# # Leave out state location info because I don't want clusters to be based on regionality

# %%
data.head()
# Out:
#        city  price    year manufacturer                   make condition  \
# 0  marshall  11900  2010.0        dodge          challenger se      good
# 2  marshall  17550  2008.0         ford                  f-150       NaN
# 3  marshall   2800  2004.0         ford                 taurus      good
# 5  marshall   9900  2007.0          gmc                  yukon      good
# 6  marshall  12500  2015.0         jeep  patriot high altitude  like new
#
#      cylinders fuel  odometer title_status  ...   type paint_color        lat  \
# 0  6 cylinders  gas   43600.0        clean  ...  coupe         red  43.477500
# 2          NaN  gas       NaN        clean  ...    NaN         NaN  44.141500
# 3  6 cylinders  gas  168591.0        clean  ...  sedan        grey  43.284500
# 5  8 cylinders  gas  169000.0        clean  ...    NaN         NaN  43.328149
# 6  4 cylinders  gas   39500.0      rebuilt  ...    SUV        grey  43.548600
#
#          long county_fips county_name  state_fips  state_code    state_name  \
# 0  -96.704100     46083.0     Lincoln        46.0          SD  South Dakota
# 2 -103.205200     46093.0       Meade        46.0          SD  South Dakota
# 3  -95.593000     19143.0     Osceola        19.0          IA          Iowa
# 5  -96.774445     46083.0     Lincoln        46.0          SD  South Dakota
# 6  -96.633200     46099.0   Minnehaha        46.0          SD  South Dakota
#
#   weather
# 0    38.0
# 2    38.0
# 3    47.0
# 5    38.0
# 6    38.0
#
# [5 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['city', 'price', 'year', 'manufacturer', 'make', 'condition',
#        'cylinders', 'fuel', 'odometer', 'title_status', 'transmission', 'vin',
#        'drive', 'size', 'type', 'paint_color', 'lat', 'long', 'county_fips',
#        'county_name', 'state_fips', 'state_code', 'state_name', 'weather'],
#       dtype='object')

# %%
# Out:
#        city  price    year manufacturer                   make condition  \
# 0  marshall  11900  2010.0        dodge          challenger se      good
# 2  marshall  17550  2008.0         ford                  f-150       NaN
# 3  marshall   2800  2004.0         ford                 taurus      good
# 5  marshall   9900  2007.0          gmc                  yukon      good
# 6  marshall  12500  2015.0         jeep  patriot high altitude  like new
#
#      cylinders fuel  odometer title_status transmission drive         size  \
# 0  6 cylinders  gas   43600.0        clean    automatic   rwd          NaN
# 2          NaN  gas       NaN        clean    automatic   NaN          NaN
# 3  6 cylinders  gas  168591.0        clean    automatic   fwd    full-size
# 5  8 cylinders  gas  169000.0        clean    automatic   4wd          NaN
# 6  4 cylinders  gas   39500.0      rebuilt    automatic   4wd  sub-compact
#
#     type paint_color county_name state_code    state_name  weather
# 0  coupe         red     Lincoln         SD  South Dakota     38.0
# 2    NaN         NaN       Meade         SD  South Dakota     38.0
# 3  sedan        grey     Osceola         IA          Iowa     47.0
# 5    NaN         NaN     Lincoln         SD  South Dakota     38.0
# 6    SUV        grey   Minnehaha         SD  South Dakota     38.0

# %%
# Convert cylinders string to just a number
def format_cylinders(x):
    if type(x) == str:
        x=x.strip(' cylinders')
    return x

# %%
data['cylinders'] = data.apply(lambda x: format_cylinders(x['cylinders']), axis=1)
data.head()
# Out:
#        city  price    year manufacturer                   make condition  \
# 0  marshall  11900  2010.0        dodge          challenger se      good
# 2  marshall  17550  2008.0         ford                  f-150       NaN
# 3  marshall   2800  2004.0         ford                 taurus      good
# 5  marshall   9900  2007.0          gmc                  yukon      good
# 6  marshall  12500  2015.0         jeep  patriot high altitude  like new
#
#   cylinders fuel  odometer title_status transmission drive         size  \
# 0         6  gas   43600.0        clean    automatic   rwd          NaN
# 2       NaN  gas       NaN        clean    automatic   NaN          NaN
# 3         6  gas  168591.0        clean    automatic   fwd    full-size
# 5         8  gas  169000.0        clean    automatic   4wd          NaN
# 6         4  gas   39500.0      rebuilt    automatic   4wd  sub-compact
#
#     type paint_color county_name state_code    state_name  weather
# 0  coupe         red     Lincoln         SD  South Dakota     38.0
# 2    NaN         NaN       Meade         SD  South Dakota     38.0
# 3  sedan        grey     Osceola         IA          Iowa     47.0
# 5    NaN         NaN     Lincoln         SD  South Dakota     38.0
# 6    SUV        grey   Minnehaha         SD  South Dakota     38.0

# %% [markdown]
# # Make a composite location string - city, state_code (don't need county)

# %%
# No missing values here so we're good
data['location'] = data.apply(lambda x: x['city']+', '+x['state_code'], axis=1)

# %%
data.head()
# Out:
#        city  price    year manufacturer                   make condition  \
# 0  marshall  11900  2010.0        dodge          challenger se      good
# 2  marshall  17550  2008.0         ford                  f-150       NaN
# 3  marshall   2800  2004.0         ford                 taurus      good
# 5  marshall   9900  2007.0          gmc                  yukon      good
# 6  marshall  12500  2015.0         jeep  patriot high altitude  like new
#
#   cylinders fuel  odometer title_status transmission drive         size  \
# 0         6  gas   43600.0        clean    automatic   rwd          NaN
# 2       NaN  gas       NaN        clean    automatic   NaN          NaN
# 3         6  gas  168591.0        clean    automatic   fwd    full-size
# 5         8  gas  169000.0        clean    automatic   4wd          NaN
# 6         4  gas   39500.0      rebuilt    automatic   4wd  sub-compact
#
#     type paint_color county_name state_code    state_name  weather  \
# 0  coupe         red     Lincoln         SD  South Dakota     38.0
# 2    NaN         NaN       Meade         SD  South Dakota     38.0
# 3  sedan        grey     Osceola         IA          Iowa     47.0
# 5    NaN         NaN     Lincoln         SD  South Dakota     38.0
# 6    SUV        grey   Minnehaha         SD  South Dakota     38.0
#
#        location
# 0  marshall, SD
# 2  marshall, SD
# 3  marshall, IA
# 5  marshall, SD
# 6  marshall, SD

# %%
# check value counts of location, should be more than cities because repeated names
# 5650 locations in dataset, almost 10 times just cities
data['location'].value_counts()
# Out:
# cosprings, CO          7651
# anchorage, AK          7568
# grandrapids, MI        7567
# sacramento, CA         7500
# sfbay, CA              7425
#                        ...
# charlottesville, WI       1
# morgantown, CA            1
# longisland, NC            1
# corvallis, MA             1
# sanantonio, FL            1
# Name: location, Length: 5650, dtype: int64

# %% [markdown]
# # Drop unnecessary columns and save file

# %%
final = data.drop(['vin','lat','long','county_fips','state_fips','city', 'county_name', 'state_code', 'state_name'], axis=1)
final.head()
# Out:
#    price    year manufacturer                   make condition cylinders fuel  \
# 0  11900  2010.0        dodge          challenger se      good         6  gas
# 2  17550  2008.0         ford                  f-150       NaN       NaN  gas
# 3   2800  2004.0         ford                 taurus      good         6  gas
# 5   9900  2007.0          gmc                  yukon      good         8  gas
# 6  12500  2015.0         jeep  patriot high altitude  like new         4  gas
#
#    odometer title_status transmission drive         size   type paint_color  \
# 0   43600.0        clean    automatic   rwd          NaN  coupe         red
# 2       NaN        clean    automatic   NaN          NaN    NaN         NaN
# 3  168591.0        clean    automatic   fwd    full-size  sedan        grey
# 5  169000.0        clean    automatic   4wd          NaN    NaN         NaN
# 6   39500.0      rebuilt    automatic   4wd  sub-compact    SUV        grey
#
#    weather      location
# 0     38.0  marshall, SD
# 2     38.0  marshall, SD
# 3     47.0  marshall, IA
# 5     38.0  marshall, SD
# 6     38.0  marshall, SD

# %%
export = final.to_csv('./data/reduced_data.csv', header=True, index = False)
