# %%
import matplotlib.pyplot as plt
import pandas as pd
mfgs = pd.read_csv('./data/mfgs.csv', header=None, index_col=0)
mfgs.columns=['Count']
mfgs.head()
# Out:
#             Count
# 0
# ford       286825
# chevrolet  256115
# toyota     113267
# honda       86059
# nissan      76993

# %%
mfgs.plot.pie(y='Count', figsize=(20,20), fontsize=20, legend=None)
